# %% [markdown]
# # Import Packages

# %%
import numpy as np
import random
from nupack import *

# %% [markdown]
# # Set Up Functions

# %%
def structure_to_bp(structure):
    """
    Converts dot parens structure to dictionary of base pairs
    
    Args:
        structure (str): dot-parens structure notation
    
    Returns:
        bp (dict): dictionary of base pair indices
    """
    open_parens = [] # List of open parentheses
    bp = {} # Dict of base pairs
    for i, x in enumerate(structure):
        if x == '(':
            open_parens.append(i)
        elif x == ')':
            open_index = open_parens.pop()
            bp[open_index] = i
            bp[i] = open_index
    return bp

def make_random_sequence(structure):
    """
    Takes a given structure and generates a random inverse 
    nucleotide sequence

    Args:
        structure (str): desired dot-parens structure notation

    Returns:
        sequence (str): generated random RNA sequence
    """
    bases = ['A', 'G', 'U', 'C']
    pairs = {'A':'U', 'G':'C', 'U':'A', 'C':'G'}
    sequence = ['_'] * len(structure)
    bp = structure_to_bp(structure)
    for i, x in enumerate(structure):
        if x == '.':
            sequence[i] = random.choice(bases)
        elif x == '(':
            sequence[i] = random.choice(bases)
            close_index = bp[i]
            sequence[close_index] = pairs[sequence[i]] 
    sequence = ''.join(sequence)
    return sequence

def nupack_analyze_sequence(sequence):
    """
    Takes given sequence and runs it through Nupack package to
    return the lowest energy RNA secondary structure
    
    Args:
        sequence (str): RNA sequence
    
    Returns:
        nupack_structure (str): predicted RNA structure from Nupack
            package
    """
    model = Model(material='rna', celsius=37) # Physical model
    A = Strand(sequence, name='A')
    tube = Tube({A: 1e-8}, complexes = SetSpec(max_size=1),
               name='Tube 1')
    results = tube_analysis(tubes=[tube], compute=['pairs', 'mfe'],
                            model=model)
    tube_result = results['(A)']
    nupack_structure = str(tube_result.mfe[0].structure)
    return nupack_structure

def mutate_random_position(mismatch, sequence, structure, constraints=None):
    """
    Mutates a random position in sequence from list of indices
    in mismatch list
    
    Args:
        mismatch (list): list of indices from which random position
            can be mutated
        sequence (str): RNA sequence
        structure (str): dot-parens notation of desired RNA structure

    Returns:
        mutated_sequence (str): mutated RNA sequence
    """
    bases = ['A', 'G', 'U', 'C']
    pairs = {'A':'U', 'G':'C', 'U':'A', 'C':'G'}
    bp = structure_to_bp(structure)
    mutate_position = random.choice(mismatch) # Question!
    sequence = list(sequence)
    sequence[mutate_position] = random.choice(bases)
    if mutate_position in bp:
        mutate_bp_position = bp[mutate_position]
        sequence[mutate_bp_position] = pairs[
            sequence[mutate_position]]
    mutated_sequence = ''.join(sequence)
    return mutated_sequence
        
def structure_differences(structure, nupack_structure):
    """
    Returns a list of indices that correspond to mismatched bases
    in ideal and predicted RNA structures
    """
    mismatch = [] # List of mismatched bases indices
    structure = list(structure)
    nupack_structure = list(nupack_structure)
    for i in range(len(structure)):
        if structure[i] != nupack_structure[i]:
            mismatch.append(i)
    return mismatch

def compare_mutate_sequence(random_sequence, structure, nupack_structure):
    """
    Compares the ideal structure to the predicted structure of
    generated random RNA sequence from Nupack
    Mutates RNA sequence randomly if structures don't match
    
    Args:
        random_sequence (str): random RNA sequence from 
            random_sequence function
        structure (str): desired dot-parens structure notation
        nupack_structure (str): dot-parens structure of random sequence
            predicted from Nupack package

    Returns:
        mutated_sequence (str):
    """
    mutated_mismatch = []
    mutated_sequence = random_sequence
#     if structure == nupack_structure:
#         print('The structures match!')
    if structure != nupack_structure:
#         print('The structures do not match!')
        mismatch = structure_differences(structure, nupack_structure)
        mutated_sequence = mutate_random_position(mismatch, random_sequence, structure)
        print('The mutated sequence is', mutated_sequence)
        mutated_nupack_structure = nupack_analyze_sequence(mutated_sequence)
        mutated_mismatch = structure_differences(structure, mutated_nupack_structure)
    return mutated_mismatch, mutated_sequence

# %%
def mutate_sequence_iterate(random_sequence, structure, nupack_structure, iterations):
    """
    Iteratively compares predicted structure from Nupack to ideal structure,
    mutates random sequence if mismatched, and adopts mutated sequence under
    certain conditions
    
    Args:
        random_sequence (str):
        structure (str):
        nupack_structure (str):
        iterations (int):

    Returns:
        final_sequence (str):
    """
    mismatch = structure_differences(structure, nupack_structure)
    for i in range(iterations):
        print('--------------------------------')
        print(f'Iteration {i}')
        print('--------------------------------')
        mutated_mismatch, mutated_sequence = compare_mutate_sequence(
            random_sequence, structure, nupack_structure)
        if len(mutated_mismatch) == 0: # Set stopping condition if structure matches
            random_sequence = mutated_sequence
            mismatch = mutated_mismatch
            print('The predicted structure is:', nupack_structure)
            print('Structure matches!')
            print('Final sequence is', random_sequence)
            break
        if len(mutated_mismatch) <= len(mismatch): # Question!
            random_sequence = mutated_sequence
            mismatch = mutated_mismatch
            nupack_structure = nupack_analyze_sequence(random_sequence)
            print('The predicted structure is:', nupack_structure)
            print('Structure is improved: Adopting sequence')
            print()
        elif len(mutated_mismatch) > len(mismatch):
            random_number = random.random()
            if random_number >= 0.95:
                random_sequence = mutated_sequence
                mismatch = mutated_mismatch
                nupack_structure = nupack_analyze_sequence(random_sequence)
                print('The predicted structure is:', nupack_structure)
                print('Structure is worse: Adopting sequence')
                print()
            else:
                print('The predicted structure is:', nupack_structure)
                print('Structure is worse: Not adopting sequence')
                print()
        if i == iterations - 1 and len(mismatch) > 0:
            print('Sequence does not converge to ideal sequence')
            print('Final sequence is', random_sequence)
            print('The predicted structure is:', nupack_structure)
    final_sequence = random_sequence
    return final_sequence

# %% [markdown]
# # Test Simple RNA Sequence

# %%
structure = '...((((.....))))..((.....)).(((.......)))'

# %%
random_sequence = make_random_sequence(structure)

# %%
print(random_sequence)
# Out:
# UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG

# %%
nupack_structure = nupack_analyze_sequence(random_sequence)

# %%
print(nupack_structure)
# Out:
# .....(((((((............))).)))).........

# %%
mutate_sequence_iterate(random_sequence, structure, nupack_structure, 100)
# Out:
# --------------------------------
# Iteration 0
# --------------------------------
# The mutated sequence is UACACGGAGCUGCCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 1
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUACUUAGCUUAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 2
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGGUCUUACACUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 3
# --------------------------------
# The mutated sequence is UACCCGCAGCUGGCGGCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 4
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCGGCUUAGCUCCG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 5
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 6
# --------------------------------
# The mutated sequence is UACAUGCAGCUGGCAUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 7
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 8
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 9
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 10
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 11
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 12
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 13
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 14
# --------------------------------
# The mutated sequence is UACACGCAGCUGGCGUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: .....(((((((............))).)))).........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 15
# --------------------------------
# The mutated sequence is UACAAGCAGCUGGCUUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 16
# --------------------------------
# The mutated sequence is UACAAGCAGCUGGCUUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 17
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 18
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGUUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 19
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGUGUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 20
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 21
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGCUUAGCUCAG
# The predicted structure is: ...(((((((((............))).)))))).......
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 22
# --------------------------------
# The mutated sequence is UACAAGCGGCUGGCUUCGCUCUUACAGUCUGCUGAGCUCAG
# The predicted structure is: ....((((((((............))).)))))........
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 23
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUGCUGAGCUCAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 24
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 25
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 26
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 27
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 28
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 29
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 30
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 31
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCUCUCUUACAGUCUCCUGAGCUGAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 32
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUCCUGGGCUGAG
# The predicted structure is: ...(((((...)))))........((((((...))))))..
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 33
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCUUCUGGGCUAAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 34
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCUUCUGGGCUAAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 35
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCUUCUGGCCUAAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 36
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCUUCUGGGCUAAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 37
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCUUCUGGGCUAAG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 38
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCAUCUGGGCUAUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 39
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCAUCUGGGCUAUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 40
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGGUCUUACACUCAUCUGGGCUAUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 41
# --------------------------------
# The mutated sequence is UACAAGCUGCUGGCUUCGCUCUUACAGUCAUCUGGGCUAUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 42
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCAUCUGGGCUAUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 43
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCAGCUGGGCUCUG
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 44
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUGAUCUGGGCUAUC
# The predicted structure is: ...(((((...))))).((((............))))....
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 45
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCACCUGGGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 46
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCACCUGGGGUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 47
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUACAGUCACCUGUGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 48
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUAGAGUCACCUGGGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 49
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCACUUACUGUCACCUGGGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 50
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGAUCUUACAUUCACCUGGGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 51
# --------------------------------
# The mutated sequence is UACAAGCCGCUGGCUUCGCUCUUCCAGUCACCUGGGCUGUG
# The predicted structure is: ...(((((...)))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 52
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUACAGUCACCUGGGCUGUG
# The predicted structure is: ...((((.....))))......(((((((.....)))))))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 53
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUACAGUCACCUGUGCUGUG
# The predicted structure is: ...((((.....))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 54
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUACAGUCACCUGGGCAGUG
# The predicted structure is: ...((((.....))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 55
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUCCAGUCACCUGGGCUGUG
# The predicted structure is: ...((((.....))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 56
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUACAGUCACCUGGGCGGUG
# The predicted structure is: ...((((.....))))......(((((((.....)))))))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 57
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGUUCUUACAAUCACCUGGGCUGUG
# The predicted structure is: (((.((((..........................)))))))
# Structure is worse: Adopting sequence
#
# --------------------------------
# Iteration 58
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGUCUUACACUCACCUGGGCUGUG
# The predicted structure is: ...((((.....))))((((((...........))))))..
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 59
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGUCUUACACUCCCCUGGGCUGGG
# The predicted structure is: ...((((.....))))((((((...........))))))..
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 60
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGUCUUACACUCCCCUGGGGUGGG
# The predicted structure is: ...((((.....))))((((((...........))))))..
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 61
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGUCUUACACUCCCCUGGCCUGGG
# The predicted structure is: ...((((.....))))((((((...........))))))..
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 62
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCCUGGGCUGGG
# The predicted structure is: ...((((.....)))).((........))(((......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 63
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCGUGGGCUGGG
# The predicted structure is: ...((((.....)))).((........))(((......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 64
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 65
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGACCUUACGUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 66
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGACCUUACGUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 67
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 68
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCUCUUACAGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 69
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGUUCUUACAAUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 70
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAGCUUACCUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 71
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 72
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAGCUUACCUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 73
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAACUUACUUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 74
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAGCUUACCUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 75
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGACUUACUCUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 76
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 77
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGUUCUUACAAUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 78
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGACCUUACGUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 79
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 80
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAUCUUACAUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 81
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAACUUACUUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 82
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGAACUUACUUUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))............(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 83
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGACUUACUCUCCCUUGGGCUGGG
# The predicted structure is: ...((((((.......))).))).....(((.......)))
# Structure is worse: Adopting sequence
#
# --------------------------------
# Iteration 84
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGGACUUACUCUCCCUUGGGCUGGG
# The predicted structure is: ...((((((.......))).))).....(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 85
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))...((.....))(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 86
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGUACUUACUAUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....))))...((.....))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 87
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 88
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCCCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 89
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGGCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 90
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCCCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 91
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 92
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 93
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 94
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGACCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 95
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCACACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 96
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGGCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 97
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is improved: Adopting sequence
#
# --------------------------------
# Iteration 98
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# --------------------------------
# Iteration 99
# --------------------------------
# The mutated sequence is UACAAGCCGCUUGCUUCGCACUUACUGUCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
# Structure is worse: Not adopting sequence
#
# Sequence does not converge to ideal sequence
# Final sequence is UACAAGCCGCUUGCUUCGCACUUACUGCCCCUUGGGCUGGG
# The predicted structure is: ...((((.....)))).(((.....)))(((.......)))
